# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !jupyter nbextension enab le --py --sys-prefix widgetsnbextension

# !pip install gmaps
# !jupyter nbextension enable --py --sys-prefix gmaps
# Out:
# Please supply at least one subcommand: disable, enable, install, list, uninstall
# ...
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: OK

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
import sys
#from  import gkey



output_data_file = "output_data/cities.csv"
# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_data_csv= "../output_data/cities.csv"
weather_csv= pd.read_csv(weather_data_csv)
weather_csv.dropna(inplace = True)
weather_csv.head()
#print(weather_csv)
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %%
#url= "http://api.openweathermap.org/data/2.5/weather?" 
#query_url = url + "appid=" + api_key + "&q=" + city

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
locations= weather_csv[["Lat","Lng"]].astype(float)

Humidity_rate= weather_csv["Humidity"].astype(float)

# %%
fig= gmaps.figure(center=[0,0],zoom_level=2)

heat_layer= gmaps.heatmap_layer(locations, weights=Humidity_rate,
                               dissipating=False, max_intensity=100,
                               point_radius=5)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
city_weather= weather_csv.loc[weather_csv["Max Temp"] > 44]
city_num= weather_csv.loc[weather_csv["Max Temp"]< 78]
#print(city_num)
#print(city_weather)
   

city_weather.dropna(inplace = False) 
city_weather.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
# 5        5     atuona          78      PF  1558378755        76  -9.80
# 6        6   flinders           0      AU  1558378755        62 -34.58
#
#       Lng  Max Temp  Wind Speed
# 1   57.70     78.80       11.41
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05
# 5 -139.03     81.96       16.49
# 6  150.85     60.01       11.41

# %%
city_num.dropna(inplace= False)
city_num.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
# 6        6   flinders           0      AU  1558378755        62 -34.58
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05
# 6  150.85     60.01       11.41

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#city_name= weather_csv.loc["City_ID"]
target_city= "portland"
hotel_df = weather_csv.loc["City":portland]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-71fce52cfe61> in <module>
#       1 #city_name= weather_csv.loc["City_ID"]
#       2 target_city= "portland"
# ----> 3 hotel_df = weather_csv.loc["City":portland]
#       4 target_url=('https://maps.googleapis.com/maps/api/geocode/json?'
#       5 'address={0}&key={1}') .format(target_city, gkey)
#
# NameError: name 'portland' is not defined

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
markers = gmaps.marker_layer(coordinates)

fig.add_layer(markers)
fig
# Display figure
